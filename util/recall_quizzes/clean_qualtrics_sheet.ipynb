# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Quiz+B+MTurk1+10+_+5+Post_August+26%2C+2018_15.22.csv", index_col="Qualtrics ID")

# %%
new_df = df.loc[[i for i in df.index if i[1:].isdigit()]]
new_df.head()
# Out:
#                                                        Question Andrew Ying  \
# Qualtrics ID
# Q1            With a similar contrast between a partly cloud...      evokes
# Q2            True or false: you can always smell, see, or t...       FALSE
# Q3            What is the diffusion of water through a semip...     osmosis
# Q4            Now known as Administrative Professionals' Day...      touted
# Q5            True or false: portable fire extinguishers sho...        TRUE
#
#                Tyler Yep     Jenn Hu Dee Dee Thao Yinuo Yao Fangmingyu Yang  \
# Qualtrics ID
# Q1                evokes  obfuscates       evokes    evokes          evokes
# Q2                 FALSE       FALSE        FALSE     FALSE           FALSE
# Q3               osmosis     osmosis      osmosis   osmosis         osmosis
# Q4            proscribed      touted       touted    touted             NaN
# Q5                 FALSE       FALSE        FALSE      TRUE            TRUE
#
# ...

# %%
new_df = new_df.drop('Q222')
new_df.head()
# Out:
#                                                        Question Andrew Ying  \
# Qualtrics ID
# Q1            With a similar contrast between a partly cloud...      evokes
# Q2            True or false: you can always smell, see, or t...       FALSE
# Q3            What is the diffusion of water through a semip...     osmosis
# Q4            Now known as Administrative Professionals' Day...      touted
# Q5            True or false: portable fire extinguishers sho...        TRUE
#
#                Tyler Yep     Jenn Hu Dee Dee Thao Yinuo Yao Fangmingyu Yang  \
# Qualtrics ID
# Q1                evokes  obfuscates       evokes    evokes          evokes
# Q2                 FALSE       FALSE        FALSE     FALSE           FALSE
# Q3               osmosis     osmosis      osmosis   osmosis         osmosis
# Q4            proscribed      touted       touted    touted             NaN
# Q5                 FALSE       FALSE        FALSE      TRUE            TRUE
#
# ...

# %%
answers = ['evokes', 'FALSE', 'osmosis', 'touted', 'TRUE', 'FALSE', 'hampered', 'Sound Level Meter', 'marsupial', 'high viscousity', 'Rapid strong pulse, hallucinations, throbbing headache, and high body temperature', 'eloquent', 'sycophants', 'anode', 'dubious', 'Class B - Plastics, polyethylene, styrofoam', 'golden eagles', 'Flushing the chemicals off the affected area with cool, gently running water for 10 to 20 minutes', 'obfuscate', 'systematic', 'Perform chest compressions only', 'birds', 'pi bonds', 'skin', 'Between 104 to 107.6 F (40 to 42 C)', 'commensurate', 'fatuous', '2 hours', 'helicase', 'temperaments', 'aluminum', 'apotheosized', 'dead organisms', 'iconoclastic', 'False', 'insects', 'extreme water pressure', 'innervates', '40', 'Wash the wound with soap', 'gibberellins', 'become red supergiants', 'At the base of the fire', 'False', 'erudite', 'Twist your body', 'static', 'insolvent', 'head', '11', 'thermal energy', 'genetic variation', 'obsequious', 'Class B carbon dioxide fire extinguisher']
new_df['Answer'] = answers
new_df.head()
# Out:
#                                                        Question Andrew Ying  \
# Qualtrics ID
# Q1            With a similar contrast between a partly cloud...      evokes
# Q2            True or false: you can always smell, see, or t...       FALSE
# Q3            What is the diffusion of water through a semip...     osmosis
# Q4            Now known as Administrative Professionals' Day...      touted
# Q5            True or false: portable fire extinguishers sho...        TRUE
#
#                Tyler Yep     Jenn Hu Dee Dee Thao Yinuo Yao Fangmingyu Yang  \
# Qualtrics ID
# Q1                evokes  obfuscates       evokes    evokes          evokes
# Q2                 FALSE       FALSE        FALSE     FALSE           FALSE
# Q3               osmosis     osmosis      osmosis   osmosis         osmosis
# Q4            proscribed      touted       touted    touted             NaN
# Q5                 FALSE       FALSE        FALSE      TRUE            TRUE
#
# ...

# %%
new_df.to_csv('Quiz B MTurk1 10_5 Post_August 26, 2018_15.22.csv')
